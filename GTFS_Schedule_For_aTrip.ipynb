# %% [markdown]
# Goal of this example is to extract route details, stops, and schedule information for one trip of a particular route.

# %%
import pandas as pd

# %% [markdown]
# I live in Seattle, and want to find the information about bus line '7' that goes next to where I live. Seattle bus service is provided by King County Metro (KCM). I've downloaded the GTFS files for KCM from https://transitfeeds.com/. Side note: https://transitfeeds.com/ has a lot of agencies' data and you may find the one you're looking for there. I've saved KCM data under ./data/kcm/ directory. Change the directory to where you stored your gtfs feeds

# %%
bus_num = "7"

# %%
dir_path="./data/kcm"

# %% [markdown]
# Let's load routes.txt (Remember that even though the file extension is .txt, it is actually a csv file)

# %%
routes_file=dir_path+"/routes.txt"

# %%
df = pd.read_csv(routes_file)

# %% [markdown]
# Let's examine the first few rows of the csv file

# %%
df.head()
# Out:
#    route_id agency_id route_short_name  route_long_name  \
# 0    100001       KCM                1              NaN
# 1    100002       KCM               10              NaN
# 2    100003       KCM              101              NaN
# 3    100004       KCM              105              NaN
# 4    100005       KCM              106              NaN
#
#                                           route_desc  route_type  \
# 0                         Kinnear - Downtown Seattle           3
# 1                    Capitol Hill - Downtown Seattle           3
# 2           Renton Transit Center - Downtown Seattle           3
# 3           Renton Highlands - Renton Transit Center           3
# 4  Renton Transit Center - Skyway - Downtown Seattle           3
#
#                                            route_url  route_color  \
# 0  http://metro.kingcounty.gov/schedules/001/n0.html          NaN
# 1  http://metro.kingcounty.gov/schedules/010/n0.html          NaN
# 2  http://metro.kingcounty.gov/schedules/101/n0.html          NaN
# 3  http://metro.kingcounty.gov/schedules/105/n0.html          NaN
# 4  http://metro.kingcounty.gov/schedules/106/n0.html          NaN
#
#    route_text_color
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %% [markdown]
# As expected, routes.txt contains all the different routes agencies operate, their short name, and the verbal description of the path they display on buses. Let's explore this file a bit more:

# %% [markdown]
# How many routes are there?

# %%
df['route_id'].nunique()
# Out:
# 215

# %% [markdown]
# Are all these routes operated by the same agency?

# %%
df['agency_id'].nunique()
# Out:
# 4

# %% [markdown]
# Routes.txt has 4 agencies listed. What are they, and how many routes are operated by each agencies?

# %%
df['agency_id'].value_counts()
# Out:
# KCM    203
# ST       8
# KMD      2
# EOS      2
# Name: agency_id, dtype: int64

# %% [markdown]
# I didn't realize when I first started that it is possible to have information from various agencies in one GTFS feed.

# %% [markdown]
# Does the route for bus line 7 even exist in this routes.txt file?

# %%
if df.isin([bus_num]).any().any():
    print ("Yes, {} route is in the routes list".format(bus_num))
else:
    print("No. Route { } is not part of this routes list".format(bus_num))
# Out:
# Yes, 7 route is in the routes list

# %% [markdown]
# Great! Let's see what information we have about bus line 7 in this file.

# %%
print(df[df.values == bus_num].T)
# Out:
#                                                                 132
# route_id                                                     100263
# agency_id                                                       KCM
# route_short_name                                                  7
# route_long_name                                                 NaN
# route_desc           Prentice St - Rainier Beach - Downtown Seattle
# route_type                                                        3
# route_url         http://metro.kingcounty.gov/schedules/007/n0.html
# route_color                                                     NaN
# route_text_color                                                NaN

# %% [markdown]
# Let's examine this information. Check https://developers.google.com/transit/gtfs/reference/#routestxt for more information
# route_id is the internal id used by King County Metro for this particular route
# route_short_name is the bus line number
# route_desc is what one would see on the bus board display for this route, along with the short name '7'
# route_type shows '3' indicating this is a bus (as opposed to a train or a subway).
# route_url will take you to KCM's website where they display the schedule

# %% [markdown]
# Recall that a particular instance of a route is called a trip. Trip information is contained in trips.txt, and the link between these two files is the route_id. See the relations picture.

# %%
bus_route_id = df[df.values == bus_num]["route_id"]

# %%
print(bus_route_id)
# Out:
# 132    100263
# Name: route_id, dtype: int64

# %% [markdown]
# Let's load the trips.txt file. Again, remember this is a csv file with txt extension

# %%
trips_file = dir_path+"/trips.txt"

# %%
trips_df = pd.read_csv(trips_file)

# %%
bus_trips = trips_df[trips_df['route_id'].isin([bus_route_id])]

# %%
bus_trips.head()
# Out:
#        route_id  service_id   trip_id                    trip_headsign  \
# 17964    100263       75804  41980848  Rainier Beach Via Rainier Ave S
# 17965    100263       75804  41980851  Rainier Beach Via Rainier Ave S
# 17966    100263       75804  41980853  Rainier Beach Via Rainier Ave S
# 17967    100263       75804  41980857  Rainier Beach Via Rainier Ave S
# 17968    100263       75804  41980862  Rainier Beach Via Rainier Ave S
#
#       trip_short_name  direction_id  block_id  shape_id  peak_flag  fare_id
# 17964           LOCAL             0   5580995  21007003          0      101
# 17965           LOCAL             0   5580999  21007003          0      101
# 17966           LOCAL             0   5580998  21007008          0      101
# 17967           LOCAL             0   5581000  21007008          0      101
# 17968           LOCAL             0   5580995  21007003          0      101

# %% [markdown]
# As expected each line in the output has the same route_id, as we're examining bus 7 route. trip_id is a unique for each of the trips. service_id points to which kind of service this trip follows. We'll leave the rest aside for now.

# %% [markdown]
# Information about the schedule is given in stop_times.txt. The columns in stop_times.txt are : trip_id,arrival_time,departure_time,stop_id,stop_sequence,stop_headsign,pickup_type,drop_off_type,shape_dist_traveled. The one's we're currently interested in are the trip_id (to look up the trip_id we're interested in), stop_id (to figure out which stops are on this trip), arrival_time & departure_time for that stop.

# %%
stop_times_file = dir_path+"/stop_times.txt"

# %%
stop_times_df = pd.read_csv(stop_times_file)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3051: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# As always, let's examine the first few rows of this file.

# %%
stop_times_df.head()
# Out:
#     trip_id arrival_time departure_time  stop_id  stop_sequence stop_headsign  \
# 0  34745814     07:04:00       07:04:00    74232              1           NaN
# 1  34745814     07:04:18       07:04:18    74731             10           NaN
# 2  34745814     07:04:52       07:04:52    74734             13           NaN
# 3  34745814     07:05:44       07:05:44    85450             16           NaN
# 4  34745814     07:09:00       07:09:00    70516             47           NaN
#
#    pickup_type  drop_off_type  shape_dist_traveled
# 0            0              0                  0.0
# 1            0              0                435.7
# 2            0              0               1284.7
# 3            0              0               2554.8
# 4            0              0               7366.2

# %% [markdown]
# Let's pick one trip of route 7, and map its times. For simplicity we'll pick the trip mentioned in the first row of 7 routes.

# %%
a_bus_trip = bus_trips.iloc[0]

# %%
print(a_bus_trip)
# Out:
# route_id                                    100263
# service_id                                   75804
# trip_id                                   41980848
# trip_headsign      Rainier Beach Via Rainier Ave S
# trip_short_name                              LOCAL
# direction_id                                     0
# block_id                                   5580995
# shape_id                                  21007003
# peak_flag                                        0
# fare_id                                        101
# Name: 17964, dtype: object

# %% [markdown]
# Let's extract the rows from stop_times dataframe that correspond to this particular trip.

# %%
a_bus_trip_stop_times = stop_times_df.loc[stop_times_df.trip_id == a_bus_trip.trip_id]

# %%
a_bus_trip_stop_times.head()
# Out:
#          trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 652708  41980848     15:21:00       15:21:00      880              1
# 652709  41980848     15:26:00       15:26:00      430             20
# 652710  41980848     15:28:00       15:28:00      450             25
# 652711  41980848     15:31:19       15:31:19      480             30
# 652712  41980848     15:33:32       15:33:32      500             35
#
#        stop_headsign  pickup_type  drop_off_type  shape_dist_traveled
# 652708           NaN            0              0                  0.0
# 652709           NaN            0              0               2405.8
# 652710           NaN            0              0               3493.3
# 652711           NaN            0              0               4890.6
# 652712           NaN            0              0               5826.1

# %% [markdown]
# Now that we've arrival, departure times of this trip, we need to figure out the names of the stops along the way. Stops for this particular trip are in the stop_id of this data. The stop names are stored in stops.txt. Let's load that file.

# %%
stops_txt = dir_path+"/stops.txt"

# %%
stops_df = pd.read_csv(stops_txt)

# %% [markdown]
# Let's examine the first few rows of this file.

# %%
stops_df.head()
# Out:
#    stop_id  stop_code                 stop_name  stop_desc   stop_lat  \
# 0     1000        NaN         Pine St & 9th Ave        NaN  47.613415
# 1    10000        NaN  NE 55th St & 43rd Ave NE        NaN  47.668575
# 2    10005        NaN  40th Ave NE & NE 51st St        NaN  47.665886
# 3    10010        NaN  NE 55th St & 39th Ave NE        NaN  47.668579
# 4    10020        NaN  NE 55th St & 37th Ave NE        NaN  47.668579
#
#      stop_lon  zone_id  stop_url  location_type  parent_station  \
# 0 -122.332138       21       NaN              0             NaN
# 1 -122.283653        1       NaN              0             NaN
# 2 -122.284897        1       NaN              0             NaN
# 3 -122.285667        1       NaN              0             NaN
# 4 -122.288300        1       NaN              0             NaN
#
#          stop_timezone
# 0  America/Los_Angeles
# 1  America/Los_Angeles
# 2  America/Los_Angeles
# 3  America/Los_Angeles
# 4  America/Los_Angeles

# %% [markdown]
# Recall this file contains all the stops in the transit area. stop_id is the unique identifier for a stop. stop_name is what you would see at the bus stop signs. stop_lon, and stop_lat give the GPS coordinates for the stop. stop_timezone is the time zone in which the stop is. For now, we will leave the others aside.

# %% [markdown]
# We're only interested in stops that bus line 7 makes. Let's extract only those stops out.

# %%
stops = stops_df[stops_df.stop_id.isin(a_bus_trip_stop_times.stop_id)]

# %%
stop_names = stops_df[['stop_id','stop_name']]

# %% [markdown]
# So now we have the stop_ids, and arrival/departure time in one data frame, and the stop_ids, and stop_names in another. Let's combine them to get comprehensive information about the schedule for this particular trip.

# %%
a_bus_trip_stop_times.merge(stop_names, on='stop_id')
# Out:
#      trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 0   41980848     15:21:00       15:21:00      880              1
# 1   41980848     15:26:00       15:26:00      430             20
# 2   41980848     15:28:00       15:28:00      450             25
# 3   41980848     15:31:19       15:31:19      480             30
# 4   41980848     15:33:32       15:33:32      500             35
# 5   41980848     15:36:02       15:36:02      515             44
# 6   41980848     15:38:00       15:38:00     1471             50
# 7   41980848     15:39:32       15:39:32     1480             55
# 8   41980848     15:40:40       15:40:40     1490             59
# 9   41980848     15:43:00       15:43:00     8540             63
# 10  41980848     15:44:09       15:44:09     8550             68
# 11  41980848     15:46:32       15:46:32     8590             77
# 12  41980848     15:48:53       15:48:53     8608             89
# 13  41980848     15:49:39       15:49:39     8620             93
# 14  41980848     15:51:32       15:51:32     8641             99
# 15  41980848     15:53:01       15:53:01     8660            105
# 16  41980848     15:55:00       15:55:00     8681            110
# 17  41980848     15:55:36       15:55:36     8690            114
# 18  41980848     15:57:15       15:57:15     8710            118
# 19  41980848     15:58:51       15:58:51     8730            124
# 20  41980848     15:59:59       15:59:59     8740            129
# 21  41980848     16:02:00       16:02:00     8760            138
# 22  41980848     16:03:31       16:03:31     8780            145
# 23  41980848     16:04:25       16:04:25     8790            149
# 24  41980848     16:06:00       16:06:00     8810            158
# 25  41980848     16:07:18       16:07:18     8820            163
# 26  41980848     16:08:37       16:08:37     8840            171
# 27  41980848     16:09:37       16:09:37     8850            178
# 28  41980848     16:11:00       16:11:00     8870            187
# 29  41980848     16:12:39       16:12:39     8890            195
# 30  41980848     16:13:57       16:13:57     8905            199
# 31  41980848     16:15:04       16:15:04     8920            205
# 32  41980848     16:16:25       16:16:25     8940            215
# 33  41980848     16:18:16       16:18:16     8970            223
# 34  41980848     16:19:27       16:19:27     8990            226
# 35  41980848     16:21:00       16:21:00    31137            231
#
#    stop_headsign  pickup_type  drop_off_type  shape_dist_traveled  \
# 0            NaN            0              0                  0.0
# 1            NaN            0              0               2405.8
# 2            NaN            0              0               3493.3
# 3            NaN            0              0               4890.6
# 4            NaN            0              0               5826.1
# 5            NaN            0              0               6881.3
# 6            NaN            0              0               7709.5
# 7            NaN            0              0               8564.5
# 8            NaN            0              0               9188.2
# 9            NaN            0              0              10489.8
# 10           NaN            0              0              11436.8
# 11           NaN            0              0              13385.9
# 12           NaN            0              0              15314.3
# 13           NaN            0              0              15931.5
# 14           NaN            0              0              17486.8
# 15           NaN            0              0              18697.2
# 16           NaN            0              0              20322.1
# 17           NaN            0              0              20774.8
# 18           NaN            0              0              22020.6
# 19           NaN            0              0              23234.6
# 20           NaN            0              0              24089.1
# 21           NaN            0              0              25621.2
# 22           NaN            0              0              26898.8
# 23           NaN            0              0              27662.5
# 24           NaN            0              0              28998.1
# 25           NaN            0              0              30091.2
# 26           NaN            0              0              31211.9
# 27           NaN            0              0              32047.0
# 28           NaN            0              0              33219.2
# 29           NaN            0              0              34688.4
# 30           NaN            0              0              35851.5
# 31           NaN            0              0              36847.6
# 32           NaN            0              0              38051.1
# 33           NaN            0              0              39708.3
# 34           NaN            0              0              40757.2
# 35           NaN            0              0              42149.0
#
#                                           stop_name
# 0                             Virginia St & 6th Ave
# 1                                 3rd Ave & Pine St
# 2                                3rd Ave & Union St
# 3                               3rd Ave & Marion St
# 4                                3rd Ave & James St
# 5                             3rd Ave S & S Main St
# 6                          S Jackson St & 5th Ave S
# 7                      S Jackson St & Maynard Ave S
# 8                          S Jackson St & 8th Ave S
# 9                         S Jackson St & 12th Ave S
# 10                        Rainier Ave S & S King St
# 11                     Rainier Ave S & S Charles St
# 12                             Rainier Ave S & I-90
# 13                       Rainier Ave S & S State St
# 14                      Rainier Ave S & S Walker St
# 15                     Rainier Ave S & S Bayview St
# 16              Rainier Ave S & S Forest St - Bay 4
# 17  Rainier Ave S & Martin Luther King Junior Way S
# 18                      Rainier Ave S & S Walden St
# 19                    Rainier Ave S & Letitia Ave S
# 20                     Rainier Ave S & S Andover St
# 21                     Rainier Ave S & S Genesee St
# 22                      Rainier Ave S & S Alaska St
# 23                     Rainier Ave S & S Edmunds St
# 24                      Rainier Ave S & S Dawson St
# 25                     Rainier Ave S & S Brandon St
# 26                       Rainier Ave S & S Orcas St
# 27                       Rainier Ave S & S Kenny St
# 28                      Rainier Ave S & S Graham St
# 29                       Rainier Ave S & S Holly St
# 30                   Rainier Ave S & S Frontenac St
# 31                     Rainier Ave S & S Othello St
# 32                      Rainier Ave S & S Holden St
# 33                        Rainier Ave S & S Rose St
# 34                  Rainier Ave S & S Cloverdale St
# 35                   S Henderson St & Rainier Ave S

# %% [markdown]
# Voila! There we have it! The schedule for trip 41980848 of bus line 7!

# %% [markdown]
# Since we have the stop_ids, which means we have their GPS locations, it would be fun to take the above information, and to show case it in a map form, including the times! That would be for another time!
